# %% [markdown]
# <a href="https://colab.research.google.com/github/ericoandre/reconhecimento_padroes/blob/main/C%C3%B3pia_de_projeto_fava_final_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!rm -R reconhecimento_padroes
# !git clone https://github.com/ericoandre/reconhecimento_padroes.git
# Out:
# Cloning into 'reconhecimento_padroes'...
# remote: Enumerating objects: 3275, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 3275 (delta 14), reused 21 (delta 9), pack-reused 3249
# Receiving objects: 100% (3275/3275), 1.55 GiB | 35.50 MiB/s, done.
# Resolving deltas: 100% (24/24), done.
# Checking out files: 100% (3670/3670), done.

# %% [markdown]
# # imports

# %%
import os, sys

import numpy as np
import pandas as pd
import random as rn

from scipy.stats import uniform, randint, expon, loguniform

from matplotlib import pyplot as plt
import seaborn as sns
sns.set()

import cv2
from imutils import paths

from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import KFold, StratifiedKFold, RandomizedSearchCV, train_test_split, cross_val_score
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, f1_score, recall_score, precision_recall_curve, auc, roc_curve

# %tensorflow_version 2.x
import tensorflow as tf
from tensorflow import keras

from keras import backend as K
from keras.utils import np_utils
from keras.regularizers import l2
from tensorflow.keras.optimizers import SGD, Adam
from keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.models import Sequential, model_from_json
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
# %matplotlib inline
# Out:
# UsageError: Line magic function `%tensorflow_version` not found.

# %% [markdown]
# # FUNÇÕES

# %%
def loadDataSet_(arg_dataset, myDepth=1):
  print("Path", arg_dataset)
  print("[INFO] loading images...")
  imagePaths = list(paths.list_images(arg_dataset))
  data  = []
  label = []
  
  for imagePath in imagePaths:
    target = imagePath.split(os.path.sep)[-2]
    image = cv2.imread(imagePath)
    if(myDepth == 1):
      image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    elif myDepth== 0:
      image = np.ravel(cv2.cvtColor(image, cv2.COLOR_BGR2GRAY))

    data.append(image)
    label.append(target)

  data = np.array(data, dtype="float") / 255.0
  num_classes = len(list(set(label)))
  label_encoder = LabelEncoder()
  labels = label_encoder.fit_transform(label)

  if 1 <= myDepth <=3:
    data = np.array(data).reshape((data.shape[0], data.shape[1], data.shape[2], myDepth))
    labels = np_utils.to_categorical(labels, num_classes)

  return (np.array(data), np.array(labels), label_encoder)

# %%
def reset_random_seeds(SEED):
  os.environ['PYTHONHASHSEED']=str(SEED)
  tf.random.set_seed(SEED)
  tf.random.set_seed(SEED)
  np.random.seed(SEED)
  rn.seed(SEED)

# %%
def testando(melhor_modelo, x_test, y_test, description, theme='Greens'):
  # Coletando predições
  y_prob = melhor_modelo.predict_proba(x_test)[:, 1] # probabilidades para a 2a classe
  y_pred = melhor_modelo.predict(x_test) # prediçoes discretas

  # calculando a acuracia, precisao e cobertura
  acuracia = accuracy_score(y_test, y_pred)
  precisao = precision_score(y_test, y_pred)
  cobertura = recall_score(y_test, y_pred) # Revocação (cobertura ou recall)
  f1_armonica = f1_score(y_test, y_pred)

  # calculando a curva
  curva_precisao, curva_cobertura, thresholds = precision_recall_curve(y_test, y_prob)

  # calculando a área sob a curva
  auc_precisao_cobertura = auc(curva_cobertura, curva_precisao)
  matrix_confusion = confusion_matrix(y_test, y_pred)
  tn, fp, fn, tp = matrix_confusion.ravel()
  #matrix_confusion = np.array([[tp, fn], [fp, tn]])

  scores_dict[description] = [acuracia,auc_precisao_cobertura, precisao,cobertura,f1_armonica, (tn, fp, fn, tp)]

  # imprimindo
  print('----- ------------------------- -----')
  print("Acurácia de teste = {:.3f}".format(acuracia))
  print("AUC = {:.3f}".format(auc_precisao_cobertura))
  print("Precisão = {:.3f}, cobertura = {:.3f}".format(precisao, cobertura))
  print("F1 = {:.3f}".format(f1_armonica))
  print('----- ------------------------- -----')

  fpr, tpr, thresholds = roc_curve(y_test, y_prob) 


  fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=False)
  fig.suptitle(description)
  sns.heatmap(matrix_confusion,annot=True, fmt='g', linewidth=0.3,cmap=theme,cbar=True, ax=axes[0],xticklabels=classes_label, yticklabels=classes_label)
    
  axes[0].annotate('VN', (0.3,0.5), fontweight='bold')
  axes[0].annotate('FP', (1.3,0.5), fontweight='bold')
  axes[0].annotate('FN', (0.3,1.5), fontweight='bold')
  axes[0].annotate('VP', (1.3,1.5), fontweight='bold')

  axes[1].plot(curva_cobertura, curva_precisao)
  axes[1].set_xlabel('Recall')
  axes[1].set_ylabel('Precision')

  axes[2].plot(fpr, tpr)
  axes[2].plot([0, 1], ls="--")
  axes[2].plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
  axes[2].set_xlabel('True Positive Rate')
  axes[2].set_ylabel('False Positive Rate')
  plt.show()

  print([acuracia,auc_precisao_cobertura, precisao,cobertura,f1_armonica, (tn, fp, fn, tp)])

# %% [markdown]
# # Atributos

# %%
#Atributos
seed = 42
largura=200
altura=267
teste_size=0.3

arg_epochs = 20
custon_batch_size = 32
custon_depth=3

scores_dict = dict()

reset_random_seeds(seed)
classes_label = ['fava cearense','orelha de vo']
arg_dataset = "reconhecimento_padroes/imagens_aumentada_mascara{}x{}".format(largura,altura)

# %% [markdown]
# # Modelos Simplies

# %%
tree_parametros = {
    "tree__criterion": ["gini", "entropy"],
    "tree__splitter": ["best", "random"],
    "tree__min_samples_split": uniform(loc=0, scale=1),
    "tree__min_samples_leaf":  uniform(loc=1e-6, scale=0.5),
    "tree__max_leaf_nodes": randint(1, 1000),
    "tree__max_depth": randint(1, 1000),
}

knn_parametros = {
    "knn__n_neighbors": randint(1, 50),
}
mlp_params = {
    "mlp__hidden_layer_sizes": randint(1, 100),
    "mlp__activation": ["identity", "logistic", "tanh", "relu"],
    "mlp__learning_rate_init": expon(loc=1e-6, scale=0.1),
    "mlp__max_iter": randint(1, 1000),
    "mlp__momentum": uniform(loc=0.5,scale=0.4999),
    "mlp__solver" : ["lbfgs", "sgd", "adam"]
}
svm_params = {
    "svm__C": loguniform(1e-4, 1e2),
    "svm__kernel": ["poly","rbf","linear"],
    "svm__degree": randint(2,5),
    "svm__gamma": loguniform(1e-4, 1e2), 
}
gaussian_parametros = {
    'gaussian__var_smoothing': [1e-11, 1e-10, 1e-9]
}
interacao=10
kf = StratifiedKFold(n_splits=5, random_state=seed, shuffle=True)

# %%
X, y, encode = loadDataSet_(arg_dataset, myDepth=0)
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=teste_size, random_state=seed)
# Out:
# Path reconhecimento_padroes/imagens_aumentada_mascara200x267
# [INFO] loading images...

# %% [markdown]
# ## Classificadores

# %%
pipe = Pipeline([('scaler', StandardScaler()), ('gaussian', GaussianNB())])

gaussian_best_model = RandomizedSearchCV(pipe, gaussian_parametros, n_iter=3, cv=kf, refit=True)
gaussian_best_model = gaussian_best_model.fit(x_train, y_train)
gaussian_yfit = gaussian_best_model.predict(x_test)

description = "NAIVE BAYES"
# print(gaussian_best_model.best_estimator_)
print("[INFO] {} ... Best params: {}\n".format(description, gaussian_best_model.best_params_))
print('----- Evaluation on Test Data -----')
print(classification_report(y_test, gaussian_yfit, target_names=classes_label))
testando(gaussian_best_model, x_test, y_test, description, 'Blues')
# Out:
# [INFO] NAIVE BAYES ... Best params: {'gaussian__var_smoothing': 1e-11}
#
# ----- Evaluation on Test Data -----
#                precision    recall  f1-score   support
#
# fava cearense       0.63      0.72      0.67       194
#  orelha de vo       0.72      0.62      0.67       219
#
#      accuracy                           0.67       413
#     macro avg       0.67      0.67      0.67       413
#  weighted avg       0.67      0.67      0.67       413
#
# ----- ------------------------- -----
# Acurácia de teste = 0.668
# AUC = 0.775
# Precisão = 0.716, cobertura = 0.621
# F1 = 0.665
# ----- ------------------------- -----
# [0.6682808716707022, 0.7752092969980212, 0.7157894736842105, 0.6210045662100456, 0.6650366748166259, (140, 54, 83, 136)]

# %%
pipe = Pipeline([('scaler', StandardScaler()), ('tree', DecisionTreeClassifier())])

tree_best_model = RandomizedSearchCV(pipe, tree_parametros,n_iter=interacao, cv=kf, refit=True)
tree_best_model = tree_best_model.fit(x_train, y_train)
tree_yfit = tree_best_model.predict(x_test)

description = "DECISION TREE"
#print(tree_best_model.best_estimator_)
print("[INFO] {} ... Best params: {}\n".format(description, tree_best_model.best_params_))
print('----- Evaluation on Test Data -----')
print(classification_report(y_test, tree_yfit, target_names=classes_label))
testando(tree_best_model, x_test, y_test, description, 'BuGn')
# Out:
# [INFO] DECISION TREE ... Best params: {'tree__criterion': 'entropy', 'tree__max_depth': 314, 'tree__max_leaf_nodes': 22, 'tree__min_samples_leaf': 0.003534152609858703, 'tree__min_samples_split': 0.023062425041415757, 'tree__splitter': 'best'}
#
# ----- Evaluation on Test Data -----
#                precision    recall  f1-score   support
#
# fava cearense       0.81      0.69      0.74       194
#  orelha de vo       0.76      0.85      0.80       219
#
#      accuracy                           0.78       413
#     macro avg       0.78      0.77      0.77       413
#  weighted avg       0.78      0.78      0.78       413
#
# ----- ------------------------- -----
# Acurácia de teste = 0.777
# AUC = 0.803
# Precisão = 0.757, cobertura = 0.854
# F1 = 0.803
# ----- ------------------------- -----
# [0.7772397094430993, 0.8034042588817568, 0.757085020242915, 0.8538812785388128, 0.8025751072961373, (134, 60, 32, 187)]

# %%
pipe = Pipeline([('scaler', StandardScaler()), ('knn', KNeighborsClassifier())])
knn_best_model = RandomizedSearchCV(pipe, knn_parametros, n_iter=interacao, cv=kf, refit=True)
knn_best_model = knn_best_model.fit(x_train, y_train)

knn_yfit = knn_best_model.predict(x_test)

description = "KNN"
# print(knn_best_model.best_estimator_)
print("[INFO] {} ... best params: {}\n".format(description, knn_best_model.best_params_))
print('----- Evaluation on Test Data -----')
print(classification_report(y_test, knn_yfit, target_names=classes_label))
testando(knn_best_model, x_test, y_test, description,'OrRd')
# Out:
# [INFO] KNN ... best params: {'knn__n_neighbors': 1}
#
# ----- Evaluation on Test Data -----
#                precision    recall  f1-score   support
#
# fava cearense       0.96      0.89      0.93       194
#  orelha de vo       0.91      0.97      0.94       219
#
#      accuracy                           0.93       413
#     macro avg       0.94      0.93      0.93       413
#  weighted avg       0.93      0.93      0.93       413
#
# ----- ------------------------- -----
# Acurácia de teste = 0.932
# AUC = 0.947
# Precisão = 0.910, cobertura = 0.968
# F1 = 0.938
# ----- ------------------------- -----
# [0.9322033898305084, 0.9474284634289657, 0.9098712446351931, 0.9680365296803652, 0.9380530973451328, (173, 21, 7, 212)]

# %%
pipe = Pipeline([('scaler', StandardScaler()), ('svm', SVC(probability=True))])
svm_best_model = RandomizedSearchCV(pipe, svm_params, n_iter=interacao, cv=kf, refit=True)
svm_best_model = svm_best_model.fit(x_train, y_train)

svm_yfit = svm_best_model.predict(x_test)

description = "SVM"
# print(svm_best_model.best_estimator_)
print("[INFO] {} ... best params: {}\n".format(description, svm_best_model.best_params_))
print('----- Evaluation on Test Data -----')
print(classification_report(y_test, svm_yfit, target_names=classes_label))
testando(svm_best_model, x_test, y_test, description, 'BuPu')
# Out:
# [INFO] SVM ... best params: {'svm__C': 0.0013304651439322366, 'svm__degree': 2, 'svm__gamma': 0.0016962756142947161, 'svm__kernel': 'linear'}
#
# ----- Evaluation on Test Data -----
#                precision    recall  f1-score   support
#
# fava cearense       0.94      0.92      0.93       201
#  orelha de vo       0.92      0.94      0.93       212
#
#      accuracy                           0.93       413
#     macro avg       0.93      0.93      0.93       413
#  weighted avg       0.93      0.93      0.93       413
#
# ----- ------------------------- -----
# Acurácia de teste = 0.930
# AUC = 0.938
# Precisão = 0.922, cobertura = 0.943
# F1 = 0.932
# ----- ------------------------- -----
# [0.9297820823244553, 0.9381082204246645, 0.9216589861751152, 0.9433962264150944, 0.9324009324009325, (184, 17, 12, 200)]

# %%
pipe = Pipeline([('scaler', StandardScaler()), ('mlp', MLPClassifier(early_stopping=True, validation_fraction=0.1))])
mlp_best_model = RandomizedSearchCV(pipe, mlp_params, n_iter=interacao, cv=kf, refit=True)
mlp_best_model = mlp_best_model.fit(x_train, y_train)

mpl_yfit = mlp_best_model.predict(x_test)

description = "MLP"
# print(mlp_best_model.best_estimator_)
print("[INFO] {} ... best params: {}\n".format(description, mlp_best_model.best_params_))
print('----- Evaluation on Test Data -----')
print(classification_report(y_test, mpl_yfit, target_names=classes_label))
testando(mlp_best_model, x_test, y_test, description, 'GnBu')
# Out:
# [INFO] MLP ... best params: {'mlp__activation': 'relu', 'mlp__hidden_layer_sizes': 60, 'mlp__learning_rate_init': 0.020262142283225707, 'mlp__max_iter': 460, 'mlp__momentum': 0.8057654149280916, 'mlp__solver': 'lbfgs'}
#
# ----- Evaluation on Test Data -----
#                precision    recall  f1-score   support
#
# fava cearense       0.96      0.93      0.94       201
#  orelha de vo       0.93      0.96      0.95       212
#
#      accuracy                           0.94       413
#     macro avg       0.95      0.94      0.94       413
#  weighted avg       0.94      0.94      0.94       413
#
# ----- ------------------------- -----
# Acurácia de teste = 0.944
# AUC = 0.958
# Precisão = 0.932, cobertura = 0.962
# F1 = 0.947
# ----- ------------------------- -----
# [0.9443099273607748, 0.9580125775589705, 0.9315068493150684, 0.9622641509433962, 0.9466357308584686, (186, 15, 8, 204)]

# %% [markdown]
# # Modelos Deep Learn

# %% [markdown]
# ## Funções

# %%
def cnn_plot(model_cnn, H1, X_teste, y_teste, description, batch_size=16):
  y_prob = model_cnn.predict(X_teste, batch_size, verbose = 0)[:, 1]
  y_pred = model_cnn.predict(X_teste)

  acuracia = accuracy_score(y_teste.argmax(axis=1), y_pred.argmax(axis=1))
  precisao = precision_score(y_teste.argmax(axis=1), y_pred.argmax(axis=1))
  cobertura = recall_score(y_teste.argmax(axis=1), y_pred.argmax(axis=1))
  f1_armonica = f1_score(y_teste.argmax(axis=1), y_pred.argmax(axis=1))

  curva_precisao, curva_cobertura, thresholds = precision_recall_curve(y_teste.argmax(axis=1), y_prob)
  auc_precisao_cobertura = auc(curva_cobertura, curva_precisao)

  matrix_confusion = confusion_matrix(y_teste.argmax(axis=1), y_pred.argmax(axis=1))
  tn, fp, fn, tp = matrix_confusion.ravel()
  fpr, tpr, thresholds = roc_curve(y_teste.argmax(axis=1), y_prob) 

  scores_dict[description] = [acuracia,auc_precisao_cobertura, precisao,cobertura,f1_armonica, (tn, fp, fn, tp)]

  # imprimindo
  print('----- ------------------------- -----')
  print("Acurácia de teste = {:.3f}".format(acuracia))
  print("AUC = {:.3f}".format(auc_precisao_cobertura))
  print("Precisão = {:.3f}, cobertura = {:.3f}".format(precisao, cobertura))
  print("F1 = {:.3f}".format(f1_armonica))
  print('----- ------------------------- -----')

  fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=False)
  fig.suptitle(description) # "CNN"

  sns.heatmap(matrix_confusion,annot=True, fmt='g', linewidth=0.3,cbar=True, ax=axes[0],xticklabels=classes_label, yticklabels=classes_label)
      
  axes[0].annotate('VN', (0.3,0.5), fontweight='bold')
  axes[0].annotate('FP', (1.3,0.5), fontweight='bold')
  axes[0].annotate('FN', (0.3,1.5), fontweight='bold')
  axes[0].annotate('VP', (1.3,1.5), fontweight='bold')

  axes[1].plot(curva_cobertura, curva_precisao)
  axes[1].set_xlabel('Recall')
  axes[1].set_ylabel('Precision')

  axes[2].plot(fpr, tpr)
  axes[2].plot([0, 1], ls="--")
  axes[2].plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
  axes[2].set_xlabel('True Positive Rate')
  axes[2].set_ylabel('False Positive Rate')
  plt.show()

  #Results
  # %matplotlib inline
  N = arg_epochs
  models = [(model_cnn, H1)]
  model_names = ["Normal", "Masked", "Augmented", "Augmented and Masked"]
  plt.rcParams["figure.figsize"] = (18,6)

  for index in range(len(models)):
    plt.subplot(len(models), 1, (index+1))
    plt.style.use("ggplot")
    plt.plot(np.arange(0, N), models[index][1].history["loss"], label="train_loss")
    plt.plot(np.arange(0, N), models[index][1].history["val_loss"], label="val_loss")
    plt.plot(np.arange(0, N), models[index][1].history["accuracy"], label="train_acc")
    plt.plot(np.arange(0, N), models[index][1].history["val_accuracy"], label="val_acc")
    plt.title("Training Loss and Accuracy on Dataset {}".format(model_names[index]))
    plt.xlabel("Epoch #")
    plt.ylabel("Loss/Accuracy")
    plt.legend(loc="lower left")

  plt.show()
  print(scores_dict[description])
  print([acuracia,auc_precisao_cobertura, precisao,cobertura,f1_armonica, (tn, fp, fn, tp)])

# %% [markdown]
# ## Leitura do data set

# %%
X_cnn, Y_cnn, label_encoder = loadDataSet_(arg_dataset, custon_depth)
X_treino_cnn, X_teste_cnn, y_treino_cnn, y_teste_cnn = train_test_split(X_cnn, Y_cnn, test_size=teste_size, random_state=seed)
# Out:
# Path reconhecimento_padroes/imagens_aumentada_mascara200x267
# [INFO] loading images...

# %% [markdown]
# ## Modelo CNN

# %%
def modelo(width, height, depth, n_class, l2_penalty):
  model = Sequential()
  
  inputShape = (height, width, depth)
  if K.image_data_format() == "channels_first":
    inputShape = (depth, height, width)
 
  model.add(Conv2D(256, (11, 11), input_shape=inputShape, padding="same", kernel_regularizer=l2_penalty))
  model.add(Activation("relu"))
  
  model.add(Conv2D(128, (5, 5), padding="same", kernel_regularizer=l2_penalty))
  model.add(Activation("relu"))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))
  
  model.add(Conv2D(64, (5, 5), padding="same", kernel_regularizer=l2_penalty))
  model.add(Activation("relu"))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))
  
  model.add(Conv2D(32, (3, 3), padding="same", kernel_regularizer=l2_penalty))
  model.add(Activation("relu"))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))
  
  model.add(Flatten())
  
  model.add(Dense(512, kernel_regularizer=l2_penalty))
  model.add(Activation("relu"))
  model.add(Dropout(0.12))
  model.add(Dense(n_class))
  model.add(Activation("softmax"))
  
  return model

# %%
def cria_model(largura, altura, custon_depth, label_encoder, arg_epochs, opt=None):
  print("[INFO] compiling model...")
  if(not opt):
    optimizer = Adam(learning_rate=1e-4, decay=1e-4 / arg_epochs)
  else:
    optimizer = SGD(learning_rate=1e-4, momentum=0.9)
  
  loss = 'binary_crossentropy'
  if len(label_encoder.classes_) > 2:
    loss = 'categorical_crossentropy'
    
  model = modelo(width=largura, height=altura, depth=custon_depth, n_class=len(label_encoder.classes_), l2_penalty=l2(0.0002))
  model.compile(loss=loss, optimizer=optimizer,metrics=["accuracy"])
  model.summary()
  return model

# %%
def treina_modelo(model, trainX, trainY, testX, testY, label_encoder, arg_epochs, custon_batch_size=32):
  print("[INFO] training network for {} epochs...".format(arg_epochs))
  H = model.fit(trainX, trainY, validation_data=(testX, testY), batch_size=custon_batch_size, epochs=arg_epochs, verbose=1)
  print("[INFO] evaluating network...")
  predictions = model.predict(testX, batch_size=custon_batch_size)
  print(classification_report(testY.argmax(axis=1), predictions.argmax(axis=1), target_names=classes_label))
  return (model, H)

# %%
model_cnn = cria_model(largura, altura, custon_depth, label_encoder_cnn, arg_epochs)
(model_cnn, H1) = treina_modelo(model_cnn, X_treino_cnn, y_treino_cnn, X_teste_cnn, y_teste_cnn, label_encoder_cnn, arg_epochs, custon_batch_size)
cnn_plot(model_cnn, H1, X_teste_cnn, y_teste_cnn, "CNN", atch_size=32)
# Out:
# [INFO] compiling model...
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 267, 200, 256)     93184
#
#  activation (Activation)     (None, 267, 200, 256)     0
#
#  conv2d_1 (Conv2D)           (None, 267, 200, 128)     819328
#
#  activation_1 (Activation)   (None, 267, 200, 128)     0
#
#  max_pooling2d (MaxPooling2D  (None, 133, 100, 128)    0
#  )
#
#  dropout (Dropout)           (None, 133, 100, 128)     0
#
#  conv2d_2 (Conv2D)           (None, 133, 100, 64)      204864
#
#  activation_2 (Activation)   (None, 133, 100, 64)      0
#
#  max_pooling2d_1 (MaxPooling  (None, 66, 50, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 66, 50, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 66, 50, 32)        18464
#
#  activation_3 (Activation)   (None, 66, 50, 32)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 33, 25, 32)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 33, 25, 32)        0
#
#  flatten (Flatten)           (None, 26400)             0
#
#  dense (Dense)               (None, 512)               13517312
#
#  activation_4 (Activation)   (None, 512)               0
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 2)                 1026
#
#  activation_5 (Activation)   (None, 2)                 0
#
# =================================================================
# Total params: 14,654,178
# Trainable params: 14,654,178
# Non-trainable params: 0
# _________________________________________________________________
# [INFO] training network for 50 epochs...
# Epoch 1/50
# 31/31 [==============================] - 235s 5s/step - loss: 0.9377 - accuracy: 0.5536 - val_loss: 0.9097 - val_accuracy: 0.5787
# Epoch 2/50
# 31/31 [==============================] - 109s 4s/step - loss: 0.8810 - accuracy: 0.6337 - val_loss: 0.8495 - val_accuracy: 0.6150
# Epoch 3/50
# 31/31 [==============================] - 109s 4s/step - loss: 0.7397 - accuracy: 0.7627 - val_loss: 0.6910 - val_accuracy: 0.8741
# Epoch 4/50
# 31/31 [==============================] - 110s 4s/step - loss: 0.6398 - accuracy: 0.8158 - val_loss: 0.5418 - val_accuracy: 0.8644
# Epoch 5/50
# 31/31 [==============================] - 110s 4s/step - loss: 0.4499 - accuracy: 0.9011 - val_loss: 0.5936 - val_accuracy: 0.8160
# Epoch 6/50
# 31/31 [==============================] - 111s 4s/step - loss: 0.3506 - accuracy: 0.9532 - val_loss: 0.4142 - val_accuracy: 0.9322
# Epoch 7/50
# 31/31 [==============================] - 110s 4s/step - loss: 0.2899 - accuracy: 0.9719 - val_loss: 0.3308 - val_accuracy: 0.9540
# Epoch 8/50
# 31/31 [==============================] - 111s 4s/step - loss: 0.2295 - accuracy: 0.9875 - val_loss: 0.3398 - val_accuracy: 0.9685
# Epoch 9/50
# 31/31 [==============================] - 111s 4s/step - loss: 0.2266 - accuracy: 0.9875 - val_loss: 0.2933 - val_accuracy: 0.9661
# Epoch 10/50
# 31/31 [==============================] - 111s 4s/step - loss: 0.2106 - accuracy: 0.9896 - val_loss: 0.3315 - val_accuracy: 0.9613
# Epoch 11/50
# 31/31 [==============================] - 111s 4s/step - loss: 0.1836 - accuracy: 0.9958 - val_loss: 0.2990 - val_accuracy: 0.9855
# Epoch 12/50
# 31/31 [==============================] - 111s 4s/step - loss: 0.1756 - accuracy: 0.9958 - val_loss: 0.4362 - val_accuracy: 0.9467
# Epoch 13/50
# 31/31 [==============================] - 111s 4s/step - loss: 0.1778 - accuracy: 0.9958 - val_loss: 0.3077 - val_accuracy: 0.9734
# Epoch 14/50
# 31/31 [==============================] - 111s 4s/step - loss: 0.1616 - accuracy: 0.9990 - val_loss: 0.3770 - val_accuracy: 0.9588
# Epoch 15/50
# 31/31 [==============================] - 113s 4s/step - loss: 0.1577 - accuracy: 1.0000 - val_loss: 0.2978 - val_accuracy: 0.9734
# Epoch 16/50
# 31/31 [==============================] - 112s 4s/step - loss: 0.1532 - accuracy: 0.9990 - val_loss: 0.2930 - val_accuracy: 0.9734
# Epoch 17/50
# 31/31 [==============================] - 111s 4s/step - loss: 0.1505 - accuracy: 1.0000 - val_loss: 0.3096 - val_accuracy: 0.9709
# Epoch 18/50
# 31/31 [==============================] - 112s 4s/step - loss: 0.1466 - accuracy: 1.0000 - val_loss: 0.3210 - val_accuracy: 0.9734
# Epoch 19/50
# 31/31 [==============================] - 111s 4s/step - loss: 0.1486 - accuracy: 0.9990 - val_loss: 0.3168 - val_accuracy: 0.9734
# Epoch 20/50
# 31/31 [==============================] - 112s 4s/step - loss: 0.1433 - accuracy: 1.0000 - val_loss: 0.3217 - val_accuracy: 0.9709
# Epoch 21/50
# 31/31 [==============================] - 111s 4s/step - loss: 0.1397 - accuracy: 1.0000 - val_loss: 0.2961 - val_accuracy: 0.9734
# Epoch 22/50
# 31/31 [==============================] - 112s 4s/step - loss: 0.1372 - accuracy: 1.0000 - val_loss: 0.3087 - val_accuracy: 0.9709
# Epoch 23/50
# 31/31 [==============================] - 111s 4s/step - loss: 0.1388 - accuracy: 0.9990 - val_loss: 0.4389 - val_accuracy: 0.9637
# Epoch 24/50
# 31/31 [==============================] - 112s 4s/step - loss: 0.1924 - accuracy: 0.9844 - val_loss: 0.2730 - val_accuracy: 0.9758
# Epoch 25/50
# 31/31 [==============================] - 110s 4s/step - loss: 0.1642 - accuracy: 0.9917 - val_loss: 0.2912 - val_accuracy: 0.9709
# Epoch 26/50
# 31/31 [==============================] - 111s 4s/step - loss: 0.1405 - accuracy: 1.0000 - val_loss: 0.2800 - val_accuracy: 0.9734
# Epoch 27/50
# 31/31 [==============================] - 110s 4s/step - loss: 0.1365 - accuracy: 1.0000 - val_loss: 0.3133 - val_accuracy: 0.9734
# Epoch 28/50
# 31/31 [==============================] - 111s 4s/step - loss: 0.1312 - accuracy: 1.0000 - val_loss: 0.3102 - val_accuracy: 0.9709
# Epoch 29/50
# 31/31 [==============================] - 110s 4s/step - loss: 0.1290 - accuracy: 1.0000 - val_loss: 0.3235 - val_accuracy: 0.9709
# Epoch 30/50
# 31/31 [==============================] - 111s 4s/step - loss: 0.1280 - accuracy: 1.0000 - val_loss: 0.3253 - val_accuracy: 0.9709
# Epoch 31/50
# 31/31 [==============================] - 110s 4s/step - loss: 0.1301 - accuracy: 1.0000 - val_loss: 0.3398 - val_accuracy: 0.9734
# Epoch 32/50
# 31/31 [==============================] - 111s 4s/step - loss: 0.1303 - accuracy: 0.9990 - val_loss: 0.3068 - val_accuracy: 0.9709
# Epoch 33/50
# 31/31 [==============================] - 110s 4s/step - loss: 0.1533 - accuracy: 0.9917 - val_loss: 0.3129 - val_accuracy: 0.9758
# Epoch 34/50
# 31/31 [==============================] - 111s 4s/step - loss: 0.1474 - accuracy: 0.9948 - val_loss: 0.2870 - val_accuracy: 0.9661
# Epoch 35/50
# 31/31 [==============================] - 110s 4s/step - loss: 0.1342 - accuracy: 0.9979 - val_loss: 0.2914 - val_accuracy: 0.9758
# Epoch 36/50
# 31/31 [==============================] - 111s 4s/step - loss: 0.1232 - accuracy: 1.0000 - val_loss: 0.2943 - val_accuracy: 0.9709
# Epoch 37/50
# 31/31 [==============================] - 110s 4s/step - loss: 0.1213 - accuracy: 1.0000 - val_loss: 0.2955 - val_accuracy: 0.9709
# Epoch 38/50
# 31/31 [==============================] - 111s 4s/step - loss: 0.1210 - accuracy: 0.9990 - val_loss: 0.3126 - val_accuracy: 0.9709
# Epoch 39/50
# 31/31 [==============================] - 110s 4s/step - loss: 0.1202 - accuracy: 1.0000 - val_loss: 0.3013 - val_accuracy: 0.9758
# Epoch 40/50
# 31/31 [==============================] - 111s 4s/step - loss: 0.1174 - accuracy: 1.0000 - val_loss: 0.3781 - val_accuracy: 0.9637
# Epoch 41/50
# 31/31 [==============================] - 110s 4s/step - loss: 0.1164 - accuracy: 1.0000 - val_loss: 0.2802 - val_accuracy: 0.9758
# Epoch 42/50
# 31/31 [==============================] - 111s 4s/step - loss: 0.1142 - accuracy: 1.0000 - val_loss: 0.2898 - val_accuracy: 0.9734
# Epoch 43/50
# 31/31 [==============================] - 110s 4s/step - loss: 0.1128 - accuracy: 1.0000 - val_loss: 0.2893 - val_accuracy: 0.9782
# Epoch 44/50
# 31/31 [==============================] - 111s 4s/step - loss: 0.1114 - accuracy: 1.0000 - val_loss: 0.2941 - val_accuracy: 0.9734
# Epoch 45/50
# 31/31 [==============================] - 110s 4s/step - loss: 0.1102 - accuracy: 1.0000 - val_loss: 0.2936 - val_accuracy: 0.9734
# Epoch 46/50
# 31/31 [==============================] - 111s 4s/step - loss: 0.1090 - accuracy: 1.0000 - val_loss: 0.2938 - val_accuracy: 0.9758
# Epoch 47/50
# 31/31 [==============================] - 110s 4s/step - loss: 0.1077 - accuracy: 1.0000 - val_loss: 0.2929 - val_accuracy: 0.9782
# Epoch 48/50
# 31/31 [==============================] - 111s 4s/step - loss: 0.1066 - accuracy: 1.0000 - val_loss: 0.2927 - val_accuracy: 0.9806
# Epoch 49/50
# 31/31 [==============================] - 110s 4s/step - loss: 0.1053 - accuracy: 1.0000 - val_loss: 0.2940 - val_accuracy: 0.9806
# Epoch 50/50
# 31/31 [==============================] - 111s 4s/step - loss: 0.1041 - accuracy: 1.0000 - val_loss: 0.3021 - val_accuracy: 0.9734
# [INFO] evaluating network...
#                precision    recall  f1-score   support
#
# fava cearense       0.96      0.98      0.97       194
#  orelha de vo       0.98      0.97      0.97       219
#
#      accuracy                           0.97       413
#     macro avg       0.97      0.97      0.97       413
#  weighted avg       0.97      0.97      0.97       413
# ----- ------------------------- -----
# Acurácia de teste = 0.973
# AUC = 0.991
# Precisão = 0.981, cobertura = 0.968
# F1 = 0.975
# ----- ------------------------- -----
# [0.9733656174334141, 0.9907957915728636, 0.9814814814814815, 0.9680365296803652, 0.9747126436781608, (190, 4, 7, 212)]

# %%
from tf.keras.models import Sequential, model_from_json
modelo_json = model_cnn.to_jeson()
with open('model_cnn.json','w') as json_file:
  json_file.write(modelo_json)

model_cnn.save_weights("Pesos_cnn.hdf5")

print('Modelo Salvo')
# Out:
# Modelo Salvo

# %% [markdown]
# ## Modelo CNN RandomizedSearchCV

# %% [markdown]
# ### Funçoes

# %%
def cnn_plot_r(model_cnn, X_teste, y_teste, description):
  y_pred = model_cnn.predict(X_teste)

  acuracia = accuracy_score(y_teste.argmax(axis=1), y_pred)
  precisao = precision_score(y_teste.argmax(axis=1), y_pred)
  cobertura = recall_score(y_teste.argmax(axis=1), y_pred)
  f1_armonica = f1_score(y_teste.argmax(axis=1), y_pred)

  curva_precisao, curva_cobertura, thresholds = precision_recall_curve(y_teste.argmax(axis=1), y_pred)
  auc_precisao_cobertura = auc(curva_cobertura, curva_precisao)

  matrix_confusion = confusion_matrix(y_teste.argmax(axis=1), y_pred)
  tn, fp, fn, tp = matrix_confusion.ravel()
  fpr, tpr, thresholds = roc_curve(y_teste.argmax(axis=1), y_pred) 

  scores_dict[description] = [acuracia,auc_precisao_cobertura, precisao,cobertura,f1_armonica, (tn, fp, fn, tp)]

  # imprimindo
  print('----- ------------------------- -----')
  print("Acurácia de teste = {:.3f}".format(acuracia))
  print("AUC = {:.3f}".format(auc_precisao_cobertura))
  print("Precisão = {:.3f}, cobertura = {:.3f}".format(precisao, cobertura))
  print("F1 = {:.3f}".format(f1_armonica))
  print('----- ------------------------- -----')

  fig, axes = plt.subplots(1, 3, figsize=(18, 6), sharey=False)
  fig.suptitle(description)

  sns.heatmap(matrix_confusion,annot=True, fmt='g', linewidth=0.3,cbar=True, ax=axes[0]) # ,xticklabels=classes_label, yticklabels=classes_label
      
  axes[0].annotate('VN', (0.3,0.5), fontweight='bold')
  axes[0].annotate('FP', (1.3,0.5), fontweight='bold')
  axes[0].annotate('FN', (0.3,1.5), fontweight='bold')
  axes[0].annotate('VP', (1.3,1.5), fontweight='bold')

  axes[1].plot(curva_cobertura, curva_precisao)
  axes[1].set_xlabel('Recall')
  axes[1].set_ylabel('Precision')

  axes[2].plot(fpr, tpr)
  axes[2].plot([0, 1], ls="--")
  axes[2].plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
  axes[2].set_xlabel('True Positive Rate')
  axes[2].set_ylabel('False Positive Rate')
  plt.show()
  print([acuracia,auc_precisao_cobertura, precisao,cobertura,f1_armonica, (tn, fp, fn, tp)])

# %%
def modelo_cnn_r(width, height, depth, l2_penalty=l2(0.0002), optimizer='adam'):
  model = Sequential()
  n_class = len(label_encoder.classes_)
  inputShape = (height, width, depth)
  if K.image_data_format() == "channels_first":
    inputShape = (depth, height, width)
 
  model.add(Conv2D(256, (11, 11), input_shape=inputShape, padding="same", kernel_regularizer=l2_penalty))
  model.add(Activation("relu"))
  
  model.add(Conv2D(128, (5, 5), padding="same", kernel_regularizer=l2_penalty))
  model.add(Activation("relu"))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))
  
  model.add(Conv2D(64, (5, 5), padding="same", kernel_regularizer=l2_penalty))
  model.add(Activation("relu"))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))
  
  model.add(Conv2D(32, (3, 3), padding="same", kernel_regularizer=l2_penalty))
  model.add(Activation("relu"))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Dropout(0.25))
  
  model.add(Flatten())
  
  model.add(Dense(512, kernel_regularizer=l2_penalty))
  model.add(Activation("relu"))
  model.add(Dropout(0.12))
  model.add(Dense(n_class))
  model.add(Activation("softmax"))

  loss = 'binary_crossentropy'
  if n_class > 2:
    loss = 'categorical_crossentropy'

  model.compile(loss=loss, optimizer=optimizer,metrics=["accuracy"])
  
  return model

# %% [markdown]
# ### Modelo CNN

# %%
my_param_grid = {
  'epochs': [30],
  'batch_size' : [16, 32],
  'optimizer': ['adam', 'gdm']
}

modelo = KerasClassifier(build_fn=modelo_cnn_r, width=largura, height=altura,  depth=custon_depth, verbose=1)
kfold = KFold(n_splits=2, shuffle=True, random_state = seed)
modelo_cnn_rand_cv = RandomizedSearchCV(estimator=modelo, param_distributions=my_param_grid, cv=kfold, n_iter=3)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead.
#   import sys

# %%
best_model = modelo_cnn_rand_cv.fit(X_treino_cnn, y_treino_cnn)

pred_yfit = best_model.predict(X_teste_cnn)

description = "CNN_RANDOM"
# print(best_model.best_estimator_)
print("[INFO] {} ... Best params: {}\n".format(description, best_model.best_params_))
print('----- Evaluation on Test Data -----')
print(classification_report(y_teste_cnn.argmax(axis=1), pred_yfit, target_names=classes_label))
cnn_plot_r(best_model, X_teste_cnn, y_teste_cnn, description)
# Out:
# Epoch 1/30
# 30/30 [==============================] - 38s 1s/step - loss: 1.1663 - accuracy: 0.5083
# Epoch 2/30
# 30/30 [==============================] - 37s 1s/step - loss: 0.8970 - accuracy: 0.6042
# Epoch 3/30
# 30/30 [==============================] - 36s 1s/step - loss: 0.7596 - accuracy: 0.7167
# Epoch 4/30
# 30/30 [==============================] - 36s 1s/step - loss: 0.5929 - accuracy: 0.8104
# Epoch 5/30
# 30/30 [==============================] - 36s 1s/step - loss: 0.4437 - accuracy: 0.8750
# Epoch 6/30
# 30/30 [==============================] - 36s 1s/step - loss: 0.2492 - accuracy: 0.9688
# Epoch 7/30
# 30/30 [==============================] - 36s 1s/step - loss: 0.1978 - accuracy: 0.9854
# Epoch 8/30
# 30/30 [==============================] - 36s 1s/step - loss: 0.1554 - accuracy: 0.9917
# Epoch 9/30
# 30/30 [==============================] - 36s 1s/step - loss: 0.1894 - accuracy: 0.9833
# Epoch 10/30
# 30/30 [==============================] - 36s 1s/step - loss: 0.2161 - accuracy: 0.9688
# Epoch 11/30
# 30/30 [==============================] - 36s 1s/step - loss: 0.1661 - accuracy: 0.9875
# Epoch 12/30
# 30/30 [==============================] - 36s 1s/step - loss: 0.1314 - accuracy: 0.9958
# Epoch 13/30
# 30/30 [==============================] - 36s 1s/step - loss: 0.1467 - accuracy: 0.9937
# Epoch 14/30
# 30/30 [==============================] - 36s 1s/step - loss: 0.1460 - accuracy: 0.9937
# Epoch 15/30
# 30/30 [==============================] - 36s 1s/step - loss: 0.1281 - accuracy: 0.9937
# Epoch 16/30
# 30/30 [==============================] - 36s 1s/step - loss: 0.1308 - accuracy: 0.9937
# Epoch 17/30
# 30/30 [==============================] - 36s 1s/step - loss: 0.1327 - accuracy: 0.9937
# Epoch 18/30
# 30/30 [==============================] - 36s 1s/step - loss: 0.1180 - accuracy: 0.9979
# Epoch 19/30
# 30/30 [==============================] - 36s 1s/step - loss: 0.1126 - accuracy: 0.9979
# Epoch 20/30
# 30/30 [==============================] - 36s 1s/step - loss: 0.1093 - accuracy: 1.0000
# Epoch 21/30
# 30/30 [==============================] - 36s 1s/step - loss: 0.1078 - accuracy: 0.9979
# Epoch 22/30
# 30/30 [==============================] - 36s 1s/step - loss: 0.1102 - accuracy: 0.9958
# Epoch 23/30
# 30/30 [==============================] - 36s 1s/step - loss: 0.1087 - accuracy: 0.9958
# Epoch 24/30
# 30/30 [==============================] - 36s 1s/step - loss: 0.1297 - accuracy: 0.9917
# Epoch 25/30
# 30/30 [==============================] - 36s 1s/step - loss: 0.1376 - accuracy: 0.9917
# Epoch 26/30
# 30/30 [==============================] - 36s 1s/step - loss: 0.1176 - accuracy: 0.9958
# Epoch 27/30
# 30/30 [==============================] - 37s 1s/step - loss: 0.1368 - accuracy: 0.9958
# Epoch 28/30
# 30/30 [==============================] - 36s 1s/step - loss: 0.1108 - accuracy: 1.0000
# Epoch 29/30
# 30/30 [==============================] - 36s 1s/step - loss: 0.1042 - accuracy: 1.0000
# Epoch 30/30
# 30/30 [==============================] - 36s 1s/step - loss: 0.1028 - accuracy: 0.9979
# 31/31 [==============================] - 11s 344ms/step - loss: 1.2431 - accuracy: 0.8628
# Epoch 1/30
# 31/31 [==============================] - 39s 1s/step - loss: 1.0807 - accuracy: 0.5198
# Epoch 2/30
# 31/31 [==============================] - 37s 1s/step - loss: 0.8809 - accuracy: 0.5551
# Epoch 3/30
# 31/31 [==============================] - 37s 1s/step - loss: 0.8291 - accuracy: 0.6403
# Epoch 4/30
# 31/31 [==============================] - 37s 1s/step - loss: 0.8433 - accuracy: 0.6237
# Epoch 5/30
# 31/31 [==============================] - 37s 1s/step - loss: 0.7502 - accuracy: 0.6819
# Epoch 6/30
# 31/31 [==============================] - 37s 1s/step - loss: 0.6486 - accuracy: 0.7360
# Epoch 7/30
# 31/31 [==============================] - 37s 1s/step - loss: 0.5878 - accuracy: 0.7672
# Epoch 8/30
# 31/31 [==============================] - 37s 1s/step - loss: 0.5251 - accuracy: 0.8337
# Epoch 9/30
# 31/31 [==============================] - 37s 1s/step - loss: 0.3451 - accuracy: 0.9002
# Epoch 10/30
# 31/31 [==============================] - 37s 1s/step - loss: 0.2800 - accuracy: 0.9293
# Epoch 11/30
# 31/31 [==============================] - 37s 1s/step - loss: 0.2400 - accuracy: 0.9584
# Epoch 12/30
# 31/31 [==============================] - 37s 1s/step - loss: 0.1886 - accuracy: 0.9730
# Epoch 13/30
# 31/31 [==============================] - 37s 1s/step - loss: 0.1658 - accuracy: 0.9854
# Epoch 14/30
# 31/31 [==============================] - 37s 1s/step - loss: 0.1360 - accuracy: 0.9938
# Epoch 15/30
# 31/31 [==============================] - 37s 1s/step - loss: 0.1243 - accuracy: 0.9917
# Epoch 16/30
# 31/31 [==============================] - 37s 1s/step - loss: 0.1472 - accuracy: 0.9938
# Epoch 17/30
# 31/31 [==============================] - 37s 1s/step - loss: 0.1121 - accuracy: 0.9979
# Epoch 18/30
# 31/31 [==============================] - 37s 1s/step - loss: 0.1038 - accuracy: 0.9979
# Epoch 19/30
# 31/31 [==============================] - 37s 1s/step - loss: 0.0990 - accuracy: 0.9979
# Epoch 20/30
# 31/31 [==============================] - 37s 1s/step - loss: 0.0946 - accuracy: 0.9979
# Epoch 21/30
# 31/31 [==============================] - 37s 1s/step - loss: 0.2100 - accuracy: 0.9647
# Epoch 22/30
# 31/31 [==============================] - 37s 1s/step - loss: 0.1518 - accuracy: 0.9792
# Epoch 23/30
# 31/31 [==============================] - 37s 1s/step - loss: 0.1119 - accuracy: 0.9979
# Epoch 24/30
# 31/31 [==============================] - 37s 1s/step - loss: 0.1009 - accuracy: 1.0000
# Epoch 25/30
# 31/31 [==============================] - 37s 1s/step - loss: 0.0944 - accuracy: 1.0000
# Epoch 26/30
# 31/31 [==============================] - 37s 1s/step - loss: 0.0890 - accuracy: 1.0000
# Epoch 27/30
# 31/31 [==============================] - 37s 1s/step - loss: 0.0847 - accuracy: 1.0000
# Epoch 28/30
# 31/31 [==============================] - 37s 1s/step - loss: 0.0850 - accuracy: 0.9979
# Epoch 29/30
# 31/31 [==============================] - 37s 1s/step - loss: 0.0792 - accuracy: 1.0000
# Epoch 30/30
# 31/31 [==============================] - 37s 1s/step - loss: 0.0788 - accuracy: 0.9979
# 30/30 [==============================] - 11s 350ms/step - loss: 0.7672 - accuracy: 0.8792
# Epoch 1/30
# 61/61 [==============================] - 75s 1s/step - loss: 0.9720 - accuracy: 0.5505
# Epoch 2/30
# 61/61 [==============================] - 75s 1s/step - loss: 0.7906 - accuracy: 0.6212
# Epoch 3/30
# 61/61 [==============================] - 73s 1s/step - loss: 0.6938 - accuracy: 0.6951
# Epoch 4/30
# 61/61 [==============================] - 74s 1s/step - loss: 0.5215 - accuracy: 0.8033
# Epoch 5/30
# 61/61 [==============================] - 73s 1s/step - loss: 0.3746 - accuracy: 0.8970
# Epoch 6/30
# 61/61 [==============================] - 74s 1s/step - loss: 0.2402 - accuracy: 0.9625
# Epoch 7/30
# 61/61 [==============================] - 74s 1s/step - loss: 0.1902 - accuracy: 0.9781
# Epoch 8/30
# 61/61 [==============================] - 74s 1s/step - loss: 0.2504 - accuracy: 0.9532
# Epoch 9/30
# 61/61 [==============================] - 74s 1s/step - loss: 0.1624 - accuracy: 0.9854
# Epoch 10/30
# 61/61 [==============================] - 74s 1s/step - loss: 0.1431 - accuracy: 0.9906
# Epoch 11/30
# 61/61 [==============================] - 74s 1s/step - loss: 0.1774 - accuracy: 0.9854
# Epoch 12/30
# 61/61 [==============================] - 74s 1s/step - loss: 0.1576 - accuracy: 0.9875
# Epoch 13/30
# 61/61 [==============================] - 74s 1s/step - loss: 0.1269 - accuracy: 0.9979
# Epoch 14/30
# 61/61 [==============================] - 74s 1s/step - loss: 0.1096 - accuracy: 1.0000
# Epoch 15/30
# 61/61 [==============================] - 75s 1s/step - loss: 0.1186 - accuracy: 0.9938
# Epoch 16/30
# 61/61 [==============================] - 74s 1s/step - loss: 0.1225 - accuracy: 0.9969
# Epoch 17/30
# 61/61 [==============================] - 74s 1s/step - loss: 0.1221 - accuracy: 0.9906
# Epoch 18/30
# 61/61 [==============================] - 74s 1s/step - loss: 0.1035 - accuracy: 0.9979
# Epoch 19/30
# 61/61 [==============================] - 74s 1s/step - loss: 0.0941 - accuracy: 1.0000
# Epoch 20/30
# 61/61 [==============================] - 74s 1s/step - loss: 0.0885 - accuracy: 0.9990
# Epoch 21/30
# 61/61 [==============================] - 74s 1s/step - loss: 0.0842 - accuracy: 0.9979
# Epoch 22/30
# 61/61 [==============================] - 74s 1s/step - loss: 0.0804 - accuracy: 0.9990
# Epoch 23/30
# 61/61 [==============================] - 75s 1s/step - loss: 0.0891 - accuracy: 0.9948
# Epoch 24/30
# 61/61 [==============================] - 74s 1s/step - loss: 0.1079 - accuracy: 0.9927
# Epoch 25/30
# 61/61 [==============================] - 74s 1s/step - loss: 0.1573 - accuracy: 0.9813
# Epoch 26/30
# 61/61 [==============================] - 75s 1s/step - loss: 0.1231 - accuracy: 0.9927
# Epoch 27/30
# 61/61 [==============================] - 74s 1s/step - loss: 0.1113 - accuracy: 0.9969
# Epoch 28/30
# 61/61 [==============================] - 73s 1s/step - loss: 0.1066 - accuracy: 0.9958
# Epoch 29/30
# 61/61 [==============================] - 75s 1s/step - loss: 0.1333 - accuracy: 0.9886
# Epoch 30/30
# 61/61 [==============================] - 73s 1s/step - loss: 0.1064 - accuracy: 0.9969
# [INFO] CNN_RANDOM ... Best params: {'optimizer': 'adam', 'epochs': 30, 'batch_size': 16}
#
# ----- Evaluation on Test Data -----
#                precision    recall  f1-score   support
#
# fava cearense       0.99      0.92      0.95       194
#  orelha de vo       0.93      1.00      0.96       219
#
#      accuracy                           0.96       413
#     macro avg       0.96      0.96      0.96       413
#  weighted avg       0.96      0.96      0.96       413
# ----- ------------------------- -----
# Acurácia de teste = 0.959
# AUC = 0.965
# Precisão = 0.932, cobertura = 0.995
# F1 = 0.962
# ----- ------------------------- -----
# [0.9588377723970944, 0.9647395145421613, 0.9316239316239316, 0.9954337899543378, 0.9624724061810154, (178, 16, 1, 218)]

# %% [markdown]
# # Plote das metricas dos Classificadores

# %%
scores_dict = dict()
scores_dict['BAYES'] = [0.6682808716707022, 0.7752092969980212, 0.7157894736842105, 0.6210045662100456, 0.6650366748166259, (140, 54, 83, 136)]
scores_dict['TREE']  = [0.7772397094430993, 0.8034042588817568, 0.757085020242915, 0.8538812785388128, 0.8025751072961373, (134, 60, 32, 187)]
scores_dict['KNN']   = [0.9322033898305084, 0.9474284634289657, 0.9098712446351931, 0.9680365296803652, 0.9380530973451328, (173, 21, 7, 212)]
scores_dict['SVM']   = [0.9297820823244553, 0.9381082204246645, 0.9216589861751152, 0.9433962264150944, 0.9324009324009325, (184, 17, 12, 200)]
scores_dict['MPL']   = [0.9443099273607748, 0.9580125775589705, 0.9315068493150684, 0.9622641509433962, 0.9466357308584686, (186, 15, 8, 204)]
scores_dict['CNN']  = [0.9733656174334141, 0.9907957915728636, 0.9814814814814815, 0.9680365296803652, 0.9747126436781608, (190, 4, 7, 212)]
scores_dict['CNN_R']   = [0.9588377723970944, 0.9647395145421613, 0.9316239316239316, 0.9954337899543378, 0.9624724061810154, (178, 16, 1, 218)]

Metricas = pd.DataFrame.from_dict(
    scores_dict,
    orient="index",
    columns=["Accuracia", "ACC", "Precision","Recall", "F1", "Matrix Conf"],
)

Metricas.to_csv("Metricas.csv", sep=';')

# %%
Metricas
# Out:
#        Accuracia       ACC  Precision    Recall        F1         Matrix Conf
# BAYES   0.668281  0.775209   0.715789  0.621005  0.665037  (140, 54, 83, 136)
# TREE    0.777240  0.803404   0.757085  0.853881  0.802575  (134, 60, 32, 187)
# KNN     0.932203  0.947428   0.909871  0.968037  0.938053   (173, 21, 7, 212)
# SVM     0.929782  0.938108   0.921659  0.943396  0.932401  (184, 17, 12, 200)
# MPL     0.944310  0.958013   0.931507  0.962264  0.946636   (186, 15, 8, 204)
# CNN     0.973366  0.990796   0.981481  0.968037  0.974713    (190, 4, 7, 212)
# CNN_R   0.958838  0.964740   0.931624  0.995434  0.962472   (178, 16, 1, 218)

# %%
# Metricas = pd.read_csv("Metricas.csv", sep=';')

cor = ['salmon','gold','teal','plum','powderblue']
ax = Metricas.plot(kind='bar', figsize=(20, 8),color = cor, rot=50).legend(
    loc='upper left', ncol=2, title="Metricas"
)
plt.savefig('metricas.png', bbox_inches='tight')
